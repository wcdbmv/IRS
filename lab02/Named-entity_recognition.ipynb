# %%
lines = []
with open('text.txt', encoding='utf-8') as file:
    for line in file:
        lines.append(line.rstrip())

text = ' '.join(lines)

# %%
from natasha import (
    Segmenter,
    MorphVocab,

    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,

    ORG,
    NamesExtractor,

    Doc
)

segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = NamesExtractor(morph_vocab)

doc = Doc(text)

# %%
doc.segment(segmenter)
doc.tag_ner(ner_tagger)

# %%
org_spans = [span for span in doc.spans if span.type == ORG]
org_spans
# Out:
# [DocSpan(start=17, stop=27, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=159, stop=162, type='ORG', text='ОПК', tokens=[...]),
#  DocSpan(start=466, stop=476, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=553, stop=558, type='ORG', text='Ижмаш', tokens=[...]),
#  DocSpan(start=1005, stop=1011, type='ORG', text='Ростех', tokens=[...]),
#  DocSpan(start=1142, stop=1152, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=1341, stop=1381, type='ORG', text='Казённое предприятие 1.5\tСтолетие завода', tokens=[...]),
#  DocSpan(start=1548, stop=1553, type='ORG', text='Ижмаш', tokens=[...]),
#  DocSpan(start=1577, stop=1642, type='ORG', text='Концерн «Калашников» 2\tДеятельность 2.1\tРебренд..., tokens=[...]),
#  DocSpan(start=2175, stop=2179, type='ORG', text='8\tСм', tokens=[...]),
#  DocSpan(start=2243, stop=2250, type='ORG', text='Ижсталь', tokens=[...]),
#  DocSpan(start=2795, stop=2827, type='ORG', text='Ижевский железоделательный завод', tokens=[...]),
#  DocSpan(start=3255, stop=3263, type='ORG', text='Ижевский', tokens=[...]),
#  DocSpan(start=3413, stop=3442, type='ORG', text='Гороблагодатских заводов [7].', tokens=[...]),
#  DocSpan(start=3838, stop=3845, type='ORG', text='Венцель', tokens=[...]),
#  DocSpan(start=4197, stop=4229, type='ORG', text='Ижевский железоделательный завод', tokens=[...]),
#  DocSpan(start=4252, stop=4273, type='ORG', text='Военного министерства', tokens=[...]),
#  DocSpan(start=4381, stop=4408, type='ORG', text='Ижевского оружейного завода', tokens=[...]),
#  DocSpan(start=4554, stop=4581, type='ORG', text='Ижевского оружейного завода', tokens=[...]),
#  DocSpan(start=6428, stop=6444, type='ORG', text='Ижевского завода', tokens=[...]),
#  DocSpan(start=6718, stop=6737, type='ORG', text='Сестрорецком заводе', tokens=[...]),
#  DocSpan(start=7652, stop=7659, type='ORG', text='Арсенал', tokens=[...]),
#  DocSpan(start=7701, stop=7719, type='ORG', text='Национальный музей', tokens=[...]),
#  DocSpan(start=8937, stop=8961, type='ORG', text='Гороблагодатских заводов', tokens=[...]),
#  DocSpan(start=8990, stop=9006, type='ORG', text='Пермских заводов', tokens=[...]),
#  DocSpan(start=9166, stop=9193, type='ORG', text='Ижевского оружейного завода', tokens=[...]),
#  DocSpan(start=9444, stop=9458, type='ORG', text='Ижевский завод', tokens=[...]),
#  DocSpan(start=9714, stop=9731, type='ORG', text='Балтийского флота', tokens=[...]),
#  DocSpan(start=10645, stop=10660, type='ORG', text='Ижевском заводе', tokens=[...]),
#  DocSpan(start=11009, stop=11025, type='ORG', text='Ижевского завода', tokens=[...]),
#  DocSpan(start=11290, stop=11305, type='ORG', text='Ижевском заводе', tokens=[...]),
#  DocSpan(start=12012, stop=12026, type='ORG', text='Ижевский завод', tokens=[...]),
#  DocSpan(start=13219, stop=13233, type='ORG', text='Ижевский завод', tokens=[...]),
#  DocSpan(start=14159, stop=14174, type='ORG', text='Ижевском заводе', tokens=[...]),
#  DocSpan(start=14472, stop=14486, type='ORG', text='Ижевский завод', tokens=[...]),
#  DocSpan(start=14720, stop=14736, type='ORG', text='Ижевского завода', tokens=[...]),
#  DocSpan(start=15006, stop=15020, type='ORG', text='Ижевский завод', tokens=[...]),
#  DocSpan(start=15769, stop=15796, type='ORG', text='Ижевского оружейного завода', tokens=[...]),
#  DocSpan(start=16095, stop=16122, type='ORG', text='Ижевскому оружейному заводу', tokens=[...]),
#  DocSpan(start=16295, stop=16316, type='ORG', text='Военному министерству', tokens=[...]),
#  DocSpan(start=16689, stop=16738, type='ORG', text='Петербургских заводов (Путиловского и Обуховского..., tokens=[...]),
#  DocSpan(start=17132, stop=17147, type='ORG', text='Ижевском заводе', tokens=[...]),
#  DocSpan(start=18039, stop=18063, type='ORG', text='Ижевский оружейный завод', tokens=[...]),
#  DocSpan(start=18165, stop=18178, type='ORG', text='Красная Армия', tokens=[...]),
#  DocSpan(start=18207, stop=18221, type='ORG', text='Ижевский завод', tokens=[...]),
#  DocSpan(start=18232, stop=18244, type='ORG', text='Белой Армией', tokens=[...]),
#  DocSpan(start=19517, stop=19522, type='ORG', text='Иж-БК', tokens=[...]),
#  DocSpan(start=19526, stop=19533, type='ORG', text='Иж-Б-36', tokens=[...]),
#  DocSpan(start=19538, stop=19546, type='ORG', text='Иж-БК-36', tokens=[...]),
#  DocSpan(start=19644, stop=19647, type='ORG', text='ПСР', tokens=[...]),
#  DocSpan(start=20235, stop=20262, type='ORG', text='Ижевского оружейного завода', tokens=[...]),
#  DocSpan(start=20903, stop=20909, type='ORG', text='АНТ-25', tokens=[...]),
#  DocSpan(start=21135, stop=21147, type='ORG', text='Ижевской ТЭЦ', tokens=[...]),
#  DocSpan(start=21648, stop=21677, type='ORG', text='Бюро новых конструкций» (БНК)', tokens=[...]),
#  DocSpan(start=21811, stop=21835, type='ORG', text='АО «Концерн „Калашников“', tokens=[...]),
#  DocSpan(start=22207, stop=22217, type='ORG', text='Совнаркома', tokens=[...]),
#  DocSpan(start=22507, stop=22521, type='ORG', text='Ижевский завод', tokens=[...]),
#  DocSpan(start=22892, stop=22924, type='ORG', text='Ковровского механического завода', tokens=[...]),
#  DocSpan(start=23631, stop=23647, type='ORG', text='Тульского завода', tokens=[...]),
#  DocSpan(start=24116, stop=24137, type='ORG', text='Ижевский механический', tokens=[...]),
#  DocSpan(start=24172, stop=24208, type='ORG', text='Ижевского машиностроительного завода', tokens=[...]),
#  DocSpan(start=24244, stop=24264, type='ORG', text='Тульского оружейного', tokens=[...]),
#  DocSpan(start=24267, stop=24300, type='ORG', text='Подольского механического заводов', tokens=[...]),
#  DocSpan(start=25226, stop=25253, type='ORG', text='Ижевский машиностроительный', tokens=[...]),
#  DocSpan(start=25516, stop=25552, type='ORG', text='Ижевского машиностроительного завода', tokens=[...]),
#  DocSpan(start=27153, stop=27156, type='ORG', text='ПВО', tokens=[...]),
#  DocSpan(start=27865, stop=27868, type='ORG', text='М-7', tokens=[...]),
#  DocSpan(start=27872, stop=27878, type='ORG', text='ММР-06', tokens=[...]),
#  DocSpan(start=27977, stop=27982, type='ORG', text='М-120', tokens=[...]),
#  DocSpan(start=28014, stop=28019, type='ORG', text='М-100', tokens=[...]),
#  DocSpan(start=28040, stop=28044, type='ORG', text='ВДНХ', tokens=[...]),
#  DocSpan(start=28126, stop=28157, type='ORG', text='Ижевского автомобильного завода', tokens=[...]),
#  DocSpan(start=28236, stop=28238, type='ORG', text='ЦК', tokens=[...]),
#  DocSpan(start=28239, stop=28243, type='ORG', text='КПСС', tokens=[...]),
#  DocSpan(start=28378, stop=28382, type='ORG', text='АЗЛК', tokens=[...]),
#  DocSpan(start=28577, stop=28581, type='ORG', text='АЗЛК', tokens=[...]),
#  DocSpan(start=28635, stop=28639, type='ORG', text='С-49', tokens=[...]),
#  DocSpan(start=28675, stop=28681, type='ORG', text='МЦВ-50', tokens=[...]),
#  DocSpan(start=28962, stop=28967, type='ORG', text='Зенит', tokens=[...]),
#  DocSpan(start=29013, stop=29020, type='ORG', text='Зенит-2', tokens=[...]),
#  DocSpan(start=29188, stop=29193, type='ORG', text='МБО-1', tokens=[...]),
#  DocSpan(start=30209, stop=30213, type='ORG', text='БК-2', tokens=[...]),
#  DocSpan(start=30225, stop=30229, type='ORG', text='БК-5', tokens=[...]),
#  DocSpan(start=31188, stop=31196, type='ORG', text='Тайфун-3', tokens=[...]),
#  DocSpan(start=31201, stop=31205, type='ORG', text='БК-3', tokens=[...]),
#  DocSpan(start=31532, stop=31547, type='ORG', text='Советской Армии', tokens=[...]),
#  DocSpan(start=31798, stop=31811, type='ORG', text='Gustlof Werke', tokens=[...]),
#  DocSpan(start=31900, stop=31909, type='ORG', text='Гроссфусс', tokens=[...]),
#  DocSpan(start=31975, stop=32004, type='ORG', text='КБ машиностроительного завода', tokens=[...]),
#  DocSpan(start=32059, stop=32093, type='ORG', text='Ижевском машиностроительном заводе', tokens=[...]),
#  DocSpan(start=32898, stop=32901, type='ORG', text='РПК', tokens=[...]),
#  DocSpan(start=33058, stop=33061, type='ORG', text='ПКБ', tokens=[...]),
#  DocSpan(start=33195, stop=33222, type='ORG', text='Ижевский машиностроительный', tokens=[...]),
#  DocSpan(start=33991, stop=33996, type='ORG', text='Ижмаш', tokens=[...]),
#  DocSpan(start=34258, stop=34291, type='ORG', text='Ижевский машиностроительный завод', tokens=[...]),
#  DocSpan(start=34337, stop=34342, type='ORG', text='Ижмаш', tokens=[...]),
#  DocSpan(start=34380, stop=34386, type='ORG', text='Ижмаша', tokens=[...]),
#  DocSpan(start=34479, stop=34486, type='ORG', text='Renault', tokens=[...]),
#  DocSpan(start=34863, stop=34873, type='ORG', text='Ижмаш-Авто', tokens=[...]),
#  DocSpan(start=34903, stop=34909, type='ORG', text='ИжАвто', tokens=[...]),
#  DocSpan(start=34948, stop=34954, type='ORG', text='Ижмаша', tokens=[...]),
#  DocSpan(start=35065, stop=35072, type='ORG', text='Китолов', tokens=[...]),
#  DocSpan(start=35633, stop=35639, type='ORG', text='Ижмаше', tokens=[...]),
#  DocSpan(start=36035, stop=36041, type='ORG', text='Ижмаше', tokens=[...]),
#  DocSpan(start=36325, stop=36330, type='ORG', text='Сайги', tokens=[...]),
#  DocSpan(start=36429, stop=36433, type='ORG', text='Барс', tokens=[...]),
#  DocSpan(start=36437, stop=36445, type='ORG', text='БИ-7-2КО', tokens=[...]),
#  DocSpan(start=36478, stop=36483, type='ORG', text='СМ2КО', tokens=[...]),
#  DocSpan(start=36548, stop=36554, type='ORG', text='Ижмаша', tokens=[...]),
#  DocSpan(start=36558, stop=36588, type='ORG', text='Ижевского механического завода', tokens=[...]),
#  DocSpan(start=36596, stop=36623, type='ORG', text='Союз российских оружейников', tokens=[...]),
#  DocSpan(start=36705, stop=36708, type='ORG', text='СРО', tokens=[...]),
#  DocSpan(start=36755, stop=36780, type='ORG', text='Ижевском оружейном заводе', tokens=[...]),
#  DocSpan(start=36962, stop=36967, type='ORG', text='Ижмаш', tokens=[...]),
#  DocSpan(start=37007, stop=37012, type='ORG', text='Ижмаш', tokens=[...]),
#  DocSpan(start=37313, stop=37319, type='ORG', text='Ижмаша', tokens=[...]),
#  DocSpan(start=37343, stop=37370, type='ORG', text='Русской Православной церкви', tokens=[...]),
#  DocSpan(start=37515, stop=37548, type='ORG', text='Ижевский машиностроительный завод', tokens=[...]),
#  DocSpan(start=37666, stop=37679, type='ORG', text='Ростехнологии', tokens=[...]),
#  DocSpan(start=37794, stop=37828, type='ORG', text='ФГУП «Ижевский механический завод»', tokens=[...]),
#  DocSpan(start=37830, stop=37857, type='ORG', text='ОАО «КБАЛ им. Л.Н. Кошкина»', tokens=[...]),
#  DocSpan(start=37859, stop=37879, type='ORG', text='ОАО «НИТИ „Прогресс“', tokens=[...]),
#  DocSpan(start=38057, stop=38075, type='ORG', text='ГК «Ростехнологии»', tokens=[...]),
#  DocSpan(start=38090, stop=38113, type='ORG', text='Группы компаний «Ижмаш»', tokens=[...]),
#  DocSpan(start=38722, stop=38737, type='ORG', text='Арбитражный суд', tokens=[...]),
#  DocSpan(start=38755, stop=38766, type='ORG', text='ОАО «Ижмаш»', tokens=[...]),
#  DocSpan(start=38828, stop=38844, type='ORG', text='ОАО «НПО „Ижмаш“', tokens=[...]),
#  DocSpan(start=38991, stop=39011, type='ORG', text='Концерн «Калашников»', tokens=[...]),
#  DocSpan(start=39097, stop=39116, type='ORG', text='Концерна Калашников', tokens=[...]),
#  DocSpan(start=39138, stop=39154, type='ORG', text='ОАО «НПО „Ижмаш“', tokens=[...]),
#  DocSpan(start=39177, stop=39202, type='ORG', text='ОАО «Концерн „Калашников“', tokens=[...]),
#  DocSpan(start=39226, stop=39246, type='ORG', text='Концерна «Калашников', tokens=[...]),
#  DocSpan(start=39415, stop=39420, type='ORG', text='Ижмаш', tokens=[...]),
#  DocSpan(start=39425, stop=39430, type='ORG', text='Ижмех', tokens=[...]),
#  DocSpan(start=39528, stop=39538, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=39734, stop=39750, type='ORG', text='Трансмашхолдинга', tokens=[...]),
#  DocSpan(start=39782, stop=39795, type='ORG', text='Аэроэкспресса', tokens=[...]),
#  DocSpan(start=39822, stop=39838, type='ORG', text='Трансмашхолдинга', tokens=[...]),
#  DocSpan(start=39970, stop=39977, type='ORG', text='Ростеха', tokens=[...]),
#  DocSpan(start=40022, stop=40032, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=40167, stop=40177, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=40241, stop=40263, type='ORG', text='Калашников/Kalashnikov', tokens=[...]),
#  DocSpan(start=40448, stop=40459, type='ORG', text='Роспатентом', tokens=[...]),
#  DocSpan(start=40507, stop=40526, type='ORG', text='Рыбинской судоверфи', tokens=[...]),
#  DocSpan(start=40710, stop=40720, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=41031, stop=41038, type='ORG', text='Патриот', tokens=[...]),
#  DocSpan(start=41091, stop=41101, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=41839, stop=41867, type='ORG', text='Военно-промышленной комиссии', tokens=[...]),
#  DocSpan(start=42085, stop=42095, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=42136, stop=42146, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=42150, stop=42156, type='ORG', text='Байкал', tokens=[...]),
#  DocSpan(start=42161, stop=42166, type='ORG', text='Ижмаш', tokens=[...]),
#  DocSpan(start=42224, stop=42231, type='ORG', text='Апостол', tokens=[...]),
#  DocSpan(start=42256, stop=42266, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=42300, stop=42322, type='ORG', text='Калашников/Kalashnikov', tokens=[...]),
#  DocSpan(start=42724, stop=42734, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=42768, stop=42790, type='ORG', text='Калашников/Kalashnikov', tokens=[...]),
#  DocSpan(start=43085, stop=43106, type='ORG', text='Концерна «Калашников»', tokens=[...]),
#  DocSpan(start=43898, stop=43911, type='ORG', text='ТехУспех-2016', tokens=[...]),
#  DocSpan(start=43971, stop=43981, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=44780, stop=44791, type='ORG', text='НПО «Ижмаш»', tokens=[...]),
#  DocSpan(start=44811, stop=44835, type='ORG', text='АО «Концерн „Калашников“', tokens=[...]),
#  DocSpan(start=44844, stop=44868, type='ORG', text='АО "Концерн «Калашников»', tokens=[...]),
#  DocSpan(start=44919, stop=44929, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=44941, stop=44952, type='ORG', text='ГК «Ростех»', tokens=[...]),
#  DocSpan(start=44980, stop=45013, type='ORG', text='ПАО «Ижевский механический завод»', tokens=[...]),
#  DocSpan(start=45047, stop=45088, type='ORG', text='ОАО «Мытищинский машиностроительный завод', tokens=[...]),
#  DocSpan(start=45121, stop=45157, type='ORG', text='Холдинговые компании Рыбинской Верфи', tokens=[...]),
#  DocSpan(start=45198, stop=45233, type='ORG', text='АО "Судостроительный завод «Вымпел»', tokens=[...]),
#  DocSpan(start=45282, stop=45291, type='ORG', text='Zala Aero', tokens=[...]),
#  DocSpan(start=45346, stop=45362, type='ORG', text='ООО "ТРИАДА-ТКО"', tokens=[...]),
#  DocSpan(start=45380, stop=45389, type='ORG', text='Группа 99', tokens=[...]),
#  DocSpan(start=45421, stop=45445, type='ORG', text='АО «Концерн „Калашников“', tokens=[...]),
#  DocSpan(start=45534, stop=45555, type='ORG', text='Концерна «Калашникова', tokens=[...]),
#  DocSpan(start=45936, stop=45946, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=46600, stop=46620, type='ORG', text='Министерства обороны', tokens=[...]),
#  DocSpan(start=46974, stop=46984, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=47094, stop=47104, type='ORG', text='Минобороны', tokens=[...]),
#  DocSpan(start=47955, stop=47965, type='ORG', text='Армия-2016', tokens=[...]),
#  DocSpan(start=47976, stop=47986, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=48180, stop=48190, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=48366, stop=48372, type='ORG', text='Baikal', tokens=[...]),
#  DocSpan(start=48527, stop=48537, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=48593, stop=48603, type='ORG', text='Минобороны', tokens=[...]),
#  DocSpan(start=48654, stop=48663, type='ORG', text='Zala Aero', tokens=[...]),
#  DocSpan(start=48685, stop=48695, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=48936, stop=48945, type='ORG', text='Газпромом', tokens=[...]),
#  DocSpan(start=48983, stop=48993, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=49470, stop=49480, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=49501, stop=49532, type='ORG', text='Федерации практической стрельбы', tokens=[...]),
#  DocSpan(start=49542, stop=49560, type='ORG', text='Союза биатлонистов', tokens=[...]),
#  DocSpan(start=49599, stop=49631, type='ORG', text='Континентальной стрелковой лигой', tokens=[...]),
#  DocSpan(start=49668, stop=49678, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=49830, stop=49840, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=49844, stop=49876, type='ORG', text='Федерация военно-тактических игр', tokens=[...]),
#  DocSpan(start=50158, stop=50172, type='ORG', text='Главный корпус', tokens=[...]),
#  DocSpan(start=51102, stop=51112, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=51447, stop=51457, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=51656, stop=51666, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=51774, stop=51784, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=51834, stop=51844, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=52501, stop=52506, type='ORG', text='АК-12', tokens=[...]),
#  DocSpan(start=52892, stop=52894, type='ORG', text='ПБ', tokens=[...]),
#  DocSpan(start=52896, stop=52899, type='ORG', text='ПСМ', tokens=[...]),
#  DocSpan(start=53053, stop=53057, type='ORG', text='СМ-2', tokens=[...]),
#  DocSpan(start=53057, stop=53059, type='ORG', text='КО', tokens=[...]),
#  DocSpan(start=53061, stop=53069, type='ORG', text='БИ-7-2КО', tokens=[...]),
#  DocSpan(start=54327, stop=54329, type='ORG', text='МЮ', tokens=[...]),
#  DocSpan(start=54577, stop=54587, type='ORG', text='Президиума', tokens=[...]),
#  DocSpan(start=54588, stop=54605, type='ORG', text='Верховного Совета', tokens=[...]),
#  DocSpan(start=54770, stop=54780, type='ORG', text='Президиума', tokens=[...]),
#  DocSpan(start=54781, stop=54798, type='ORG', text='Верховного Совета', tokens=[...]),
#  DocSpan(start=55271, stop=55277, type='ORG', text='Ижмаша', tokens=[...]),
#  DocSpan(start=55378, stop=55388, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=55473, stop=55483, type='ORG', text='Калашников', tokens=[...]),
#  DocSpan(start=55519, stop=55539, type='ORG', text='Министерства обороны', tokens=[...]),
#  DocSpan(start=55712, stop=55729, type='ORG', text='Sickle and Hammer', tokens=[...]),
#  DocSpan(start=56390, stop=56405, type='ORG', text='Союза писателей', tokens=[...]),
#  DocSpan(start=56422, stop=56452, type='ORG', text='Совета Союза Верховного Совета', tokens=[...]),
#  DocSpan(start=56727, stop=56743, type='ORG', text='Совета Министров', tokens=[...])]

# %%
from yargy import Parser, rule, and_, not_, or_
from yargy.interpretation import fact
from yargy.predicates import gram, in_, length_eq, is_upper, is_title, eq, type
from yargy.relations import gnc_relation
from yargy.pipelines import morph_pipeline
from yargy.tokenizer import (QUOTES, LEFT_QUOTES, RIGHT_QUOTES)

QUOTE = in_(QUOTES)
LEFT_QUOTE = in_(LEFT_QUOTES)
RIGHT_QUOTE = in_(RIGHT_QUOTES)

# Организация с формой управления, типом и названием
Organisation = fact(
    'Organisation',
    ['form', 'type', 'name']
)

# Форма управления организацией
FORM_DICT = ['ОАО', 'АО', 'ГК', 'ООО', 'НПО', 'ПАО']
FORM = morph_pipeline(FORM_DICT)

# Тип организации
TYPE_DICT = [
    'союз',
    'концерн',
    'федерация',
]
TYPE = morph_pipeline(TYPE_DICT)

# Наименование организации
OrgName = rule(
    gram('ADJF').repeatable().optional(),
    and_(
        gram('NOUN'),
        not_(in_(FORM_DICT)),
        not_(in_(TYPE_DICT))
    ),
    gram('ADJF').repeatable().optional()
)

gnc = gnc_relation()
ORGANISATION = rule(
    FORM.interpretation(
        Organisation.form
    ),
    LEFT_QUOTE.optional(),
    TYPE.interpretation(
        Organisation.type
    ).optional(),
    LEFT_QUOTE.optional(),
    OrgName.interpretation(
        Organisation.name
    ),
    RIGHT_QUOTE.optional(),
    RIGHT_QUOTE.optional()
).interpretation(
    Organisation
)

parser = Parser(ORGANISATION)

matches = []
for match in parser.findall(text):
    matches.append(match.fact)

matches
# Out:
# [Organisation(
#      form='АО',
#      type='Концерн',
#      name='Калашников'
#  ),
#  Organisation(
#      form='ОАО',
#      type=None,
#      name='КБАЛ'
#  ),
#  Organisation(
#      form='ОАО',
#      type=None,
#      name='НИТИ'
#  ),
#  Organisation(
#      form='ГК',
#      type=None,
#      name='Ростехнологии'
#  ),
#  Organisation(
#      form='ОАО',
#      type=None,
#      name='Ижмаш'
#  ),
#  Organisation(
#      form='НПО',
#      type=None,
#      name='Ижмаш'
#  ),
#  Organisation(
#      form='НПО',
#      type=None,
#      name='Ижмаш'
#  ),
#  Organisation(
#      form='ОАО',
#      type='Концерн',
#      name='Калашников'
#  ),
#  Organisation(
#      form='НПО',
#      type=None,
#      name='Ижмаш'
#  ),
#  Organisation(
#      form='АО',
#      type='Концерн',
#      name='Калашников'
#  ),
#  Organisation(
#      form='ГК',
#      type=None,
#      name='Ростех'
#  ),
#  Organisation(
#      form='ПАО',
#      type=None,
#      name='Ижевский механический завод'
#  ),
#  Organisation(
#      form='ОАО',
#      type=None,
#      name='Мытищинский машиностроительный завод'
#  ),
#  Organisation(
#      form='АО',
#      type='Концерн',
#      name='Калашников'
#  )]

# %%
from yargy.predicates import is_title

# Награда - обладает типом (нп. орден) и названием
Award = fact(
    'Award',
    ['type', 'name']
)

AWARD_PRE = morph_pipeline([
    'награда',
    'награжден'
])

# Тип награды - орден или медаль с несколькими прилагательными
AWARD_TYPE_DICT = ['медаль', 'орден']
AWARD_TYPE = rule(
    gram('ADJF').repeatable().optional(),
    morph_pipeline(AWARD_TYPE_DICT)
)

# Название награды
AWARD_NAME = rule(
    LEFT_QUOTE.optional(),
    or_(
        rule(
            and_(is_title(), gram('ADJF')).repeatable(),
            gram('ADJF').optional().repeatable(),
            gram('NOUN'),
            gram('gent').repeatable().optional()
        ),
        rule(and_(is_title(), gram('gent'))),
    ),
    RIGHT_QUOTE.optional()
)

# Награда
AWARD = rule(
    or_(
        rule(
            AWARD_PRE,
            AWARD_TYPE.interpretation(
                Award.type.inflected()
            ),
            AWARD_NAME.interpretation(
                Award.name
            )
        ),
        rule(
            AWARD_PRE,
            AWARD_NAME.interpretation(
                Award.name
            )
        ),
    )
).interpretation(
    Award
)

parser = Parser(AWARD)

matches = []
for match in parser.findall(text):
    matches.append(match.fact)

matches
# Out:
# [Award(
#      type='орден',
#      name='Ленина'
#  ),
#  Award(
#      type='орден',
#      name='Трудового Красного Знамени'
#  ),
#  Award(
#      type=None,
#      name='Русской Православной церкви'
#  ),
#  Award(
#      type='орден',
#      name='Ленина'
#  ),
#  Award(
#      type='орден',
#      name='Трудового Красного Знамени'
#  ),
#  Award(
#      type='орден',
#      name='Октябрьской революции'
#  )]

# %%
from yargy.predicates import length_eq, is_upper, type as ya_type

# Стрелковое оружие с типом, названием и калибром
Weapon = fact(
    'Weapon',
    ['type', 'name', 'caliber']
)

# Тип оружия
WEAPON_TYPE = morph_pipeline([
    'карабин',
    'винтовка',
    'автомат',
    'пистолет',
    'пулемет',
    'пулемёт',
    'ружьё',
])

INT = ya_type('INT')
# Аббревиатура
ABBR = and_(
    not_(length_eq(1)),
    is_upper()
)

# Наименование оружия - аббревиатура или существительное с заглавной буквы
# с числовыми обозначениями
WEAPON_NAME = rule(
    or_(
        ABBR,
        and_(
            is_title(),
            gram('NOUN'),
            not_(length_eq(1))
        )
    ),
    INT.optional(),
    rule(
        '-',
        or_(
            rule(INT),
            rule(ABBR),
        )
    ).optional(),
)

SEP = in_(',.')

NUM = rule(
    INT,
    rule(
        SEP,
        INT
    ).optional()
)

CALIBER_WORD = morph_pipeline(
    ['калибр', 'кал', 'кал.']
)
# Числовое обозначение калибра
CALIBER_VAL = rule(
    rule('.').optional(),  # .308
    NUM,  # 5.45
    rule(  # 9x19
        in_('xх×'),
        NUM
    ).optional(),
).interpretation(Weapon.caliber)

# Калибр
CALIBER = or_(
    rule(
        in_('(').optional(),
        CALIBER_WORD,
        CALIBER_VAL,
        rule('мм').optional(),
        in_(')').optional()
    ),
    rule(
        CALIBER_WORD.optional(),
        CALIBER_VAL,
        rule('мм')
    ),
    rule(
        CALIBER_VAL,
        CALIBER_WORD
    )
)

# Оружие
WEAPON = rule(
    WEAPON_TYPE.interpretation(
        Weapon.type.inflected()
    ),
    CALIBER.optional(),
    LEFT_QUOTE.optional(),
    WEAPON_NAME.interpretation(
        Weapon.name
    ),
    RIGHT_QUOTE.optional(),
    CALIBER.optional()
).interpretation(
    Weapon
)

parser = Parser(WEAPON)

matches = []
for match in parser.findall(text):
    matches.append(match.fact)

matches
# Out:
# [Weapon(
#      type='винтовка',
#      name='Мосина',
#      caliber=None
#  ),
#  Weapon(
#      type='карабин',
#      name='Мосина',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Фёдорова',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Мосина',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Бердана',
#      caliber=None
#  ),
#  Weapon(
#      type='ружьё',
#      name='ПСР',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Мосина',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='АВС-36',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Токарева',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Мосина',
#      caliber=None
#  ),
#  Weapon(
#      type='ружьё',
#      name='Дегтярёва',
#      caliber=None
#  ),
#  Weapon(
#      type='ружьё',
#      name='Симонова',
#      caliber=None
#  ),
#  Weapon(
#      type='пулемёт',
#      name='Березина',
#      caliber=None
#  ),
#  Weapon(
#      type='пистолет',
#      name='ТТ',
#      caliber=None
#  ),
#  Weapon(
#      type='ружьё',
#      name='Дегтярёва',
#      caliber=None
#  ),
#  Weapon(
#      type='пистолет',
#      name='ТТ',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Мосина',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='ЦСВ-1',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='ЦВ-50',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Зенит',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Тайга',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Зенит-3',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Зенит-4',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='БО-59',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Стрела-3',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='СМ-2',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Биатлон-59',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Биатлон 7',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Биатлон',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='БИ-4',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='БИЛ-6',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='БК',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Урал',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Тайфун-1',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='БК-3',
#      caliber=None
#  ),
#  Weapon(
#      type='карабин',
#      name='Барс',
#      caliber=None
#  ),
#  Weapon(
#      type='карабин',
#      name='Медведь',
#      caliber=None
#  ),
#  Weapon(
#      type='карабин',
#      name='Барс',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Тайфун-1',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='МС-74',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='СВД',
#      caliber=None
#  ),
#  Weapon(
#      type='пулемёт',
#      name='MG42',
#      caliber=None
#  ),
#  Weapon(
#      type='автомат',
#      name='Калашникова',
#      caliber=None
#  ),
#  Weapon(
#      type='автомат',
#      name='Калашникова',
#      caliber=None
#  ),
#  Weapon(
#      type='автомат',
#      name='Калашникова',
#      caliber=None
#  ),
#  Weapon(
#      type='пулемёт',
#      name='Калашникова',
#      caliber=None
#  ),
#  Weapon(
#      type='пулемёт',
#      name='ПК',
#      caliber=None
#  ),
#  Weapon(
#      type='автомат',
#      name='АКС74',
#      caliber=None
#  ),
#  Weapon(
#      type='автомат',
#      name='АК74',
#      caliber=None
#  ),
#  Weapon(
#      type='автомат',
#      name='Калашникова',
#      caliber=None
#  ),
#  Weapon(
#      type='автомат',
#      name='Никонова',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='СВ-98',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='СВ-99',
#      caliber=None
#  ),
#  Weapon(
#      type='автомат',
#      name='Калашникова',
#      caliber=None
#  ),
#  Weapon(
#      type='карабин',
#      name='Тигр',
#      caliber=None
#  ),
#  Weapon(
#      type='ружьё',
#      name='Сайга-12',
#      caliber=None
#  ),
#  Weapon(
#      type='карабин',
#      name='Сайга-308',
#      caliber=None
#  ),
#  Weapon(
#      type='ружьё',
#      name='Сайга-12',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='СВК',
#      caliber=None
#  ),
#  Weapon(
#      type='пулемёт',
#      name='РПК-16',
#      caliber=None
#  ),
#  Weapon(
#      type='пистолет',
#      name='Лебедева',
#      caliber='9×19'
#  ),
#  Weapon(
#      type='автомат',
#      name='Калашникова',
#      caliber=None
#  ),
#  Weapon(
#      type='автомат',
#      name='Калашникова',
#      caliber=None
#  ),
#  Weapon(
#      type='ружьё',
#      name='Сайга-12',
#      caliber='12'
#  ),
#  Weapon(
#      type='ружьё',
#      name='Сайга-12',
#      caliber=None
#  ),
#  Weapon(
#      type='карабин',
#      name='Сайга-МК',
#      caliber='5,45×39'
#  ),
#  Weapon(
#      type='пистолет',
#      name='Макаров',
#      caliber=None
#  ),
#  Weapon(
#      type='пистолет',
#      name='Макарова',
#      caliber=None
#  ),
#  Weapon(
#      type='пистолет',
#      name='MP-446',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='СВЧ-308',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Биатлон-7',
#      caliber='7,62'
#  ),
#  Weapon(
#      type='ружьё',
#      name='Сайга-12',
#      caliber=None
#  ),
#  Weapon(
#      type='карабин',
#      name='Сайга 9',
#      caliber=None
#  ),
#  Weapon(
#      type='карабин',
#      name='Сайга-МК',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='Юнкер',
#      caliber=None
#  ),
#  Weapon(
#      type='винтовка',
#      name='ВП-АК',
#      caliber=None
#  ),
#  Weapon(
#      type='автомат',
#      name='Калашникова',
#      caliber=None
#  )]

# %%
[match for match in matches if match.caliber is not None]
# Out:
# [Weapon(
#      type='пистолет',
#      name='Лебедева',
#      caliber='9×19'
#  ),
#  Weapon(
#      type='ружьё',
#      name='Сайга-12',
#      caliber='12'
#  ),
#  Weapon(
#      type='карабин',
#      name='Сайга-МК',
#      caliber='5,45×39'
#  ),
#  Weapon(
#      type='винтовка',
#      name='Биатлон-7',
#      caliber='7,62'
#  )]
